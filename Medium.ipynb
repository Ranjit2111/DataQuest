# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('final_dataset.csv')

# %%
data.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0           x           y
# 0             0         0.0  288.520172 -257.294235
# 1             1         1.0  385.013428 -205.393753
# 2             2         2.0  505.566803 -240.178604
# 3             3         4.0  547.553528 -157.743958
# 4             4         5.0  753.258240 -156.936386
# 5             5         6.0  339.309052 -138.702263
# 6             6         7.0  490.002991 -159.167099
# 7             7         8.0  586.313904 -181.481873
# 8             8         9.0  579.106140 -217.907928
# 9             9        11.0  410.081970 -259.219742

# %%
data['Unnamed: 0'].isnull().sum()
# Out:
# 438000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1         0
# Unnamed: 0      438000
# x                    0
# y                    0
# dtype: int64

# %%
data.describe()
# Out:
#         Unnamed: 0.1  Unnamed: 0              x              y
# count  438519.000000  519.000000  438519.000000  438519.000000
# mean   219259.000000  275.346821  -26939.162615    1428.297251
# std    126589.675685  160.447814    9074.380557   19428.613416
# min         0.000000    0.000000  -43339.903361  -20988.914718
# 25%    109629.500000  133.500000  -29962.791565  -19518.462219
# 50%    219259.000000  277.000000  -28401.093735   10056.237789
# 75%    328888.500000  415.500000  -23755.246592   10896.535452
# max    438518.000000  550.000000     757.138306   34874.046230

# %%
fig= plt.figure(figsize = (10,8))
plt.scatter(data.x,data.y)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('Scatter plot')
plt.show()

# %%
positives = data[data.x > 0]
positives.shape
# Out:
# (30519, 4)

# %%
negatives = data[~(data.x > 0)]
negatives.shape
# Out:
# (408000, 4)

# %%
positives_smally = positives[positives.y < 1000]
print(positives_smally.shape)
plt.scatter(positives_smally.x,positives_smally.y)
plt.show()
# Out:
# (519, 4)

# %%
positives_bigy = positives[~(positives.y < 1000)]
print(positives_bigy.shape)
# plt.plot(positives_bigy.x,positives_bigy.y)
plt.show()
# Out:
# (30000, 4)

# %%
positives_bigy.describe()
# Out:
#         Unnamed: 0.1  Unnamed: 0             x             y
# count   30000.000000         0.0  30000.000000  30000.000000
# mean   423518.500000         NaN    386.435987  32758.768028
# std      8660.398374         NaN    244.290729   1680.895446
# min    408519.000000         NaN    120.599643  30175.644458
# 25%    416018.750000         NaN    145.096693  30931.095263
# 50%    423518.500000         NaN    321.921313  32925.562510
# 75%    431018.250000         NaN    688.399523  34574.671766
# max    438518.000000         NaN    746.245718  34874.046230

# %%
positives.y.describe()
# Out:
# count    30519.000000
# mean     32198.185663
# std       4576.339080
# min       -298.324036
# 25%      30930.785371
# 50%      32776.542331
# 75%      34574.558739
# max      34874.046230
# Name: y, dtype: float64

# %%
data.corr()
# Out:
#               Unnamed: 0.1  Unnamed: 0         x         y
# Unnamed: 0.1      1.000000    0.999910  0.800055 -0.266019
# Unnamed: 0        0.999910    1.000000 -0.005138  0.005028
# x                 0.800055   -0.005138  1.000000  0.144524
# y                -0.266019    0.005028  0.144524  1.000000

# %%
plt.hist(data.x)
plt.show()

# %%
data.x.describe()
# Out:
# count    438519.000000
# mean     -26939.162615
# std        9074.380557
# min      -43339.903361
# 25%      -29962.791565
# 50%      -28401.093735
# 75%      -23755.246592
# max         757.138306
# Name: x, dtype: float64
